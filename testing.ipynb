# %%
from spotify_helper import SpotifyHelper
import pandas as pd

# %%
df = pd.read_csv('idk.csv', index_col='id')
df
# Out:
#                                       name  popularity  explicit  date  \
# id
# 6I3mqTwhRpn34SLVafSH7G               Ghost          92     False  2021
# 02MWAaffLxlfxAUY7c5dvx          Heat Waves          94     False  2020
# 2QjOHCTQ1Jl3zawyYOpxh6     Sweater Weather          92     False  2013
# 2auYgZ1GcTkWj2bOaE2Wwm          Junya pt 2          61     False  2021
# 3ZCBSFcZSRM9Z48ew28Zrf            Souvenir          65     False  2020
# 6FZDfxM3a3UCqtzo5pxSLZ          Without Me          79      True  2020
# 7A2eDNBgJrEVE87C8pOMqN  When We Were Young           0     False  2016
#
#                                       artists  \
# id
# 6I3mqTwhRpn34SLVafSH7G      ['Justin Bieber']
# 02MWAaffLxlfxAUY7c5dvx      ['Glass Animals']
# 2QjOHCTQ1Jl3zawyYOpxh6  ['The Neighbourhood']
# 2auYgZ1GcTkWj2bOaE2Wwm         ['Kanye West']
# 3ZCBSFcZSRM9Z48ew28Zrf       ['Selena Gomez']
# 6FZDfxM3a3UCqtzo5pxSLZ             ['Halsey']
# 7A2eDNBgJrEVE87C8pOMqN              ['Adele']
#
# ...
