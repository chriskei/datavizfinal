# %%
from spotify_helper import SpotifyHelper
import pandas as pd

# %%
df = pd.read_csv('test.csv')

df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.601   0.741    2    -5.569     1       0.0478        0.1850
# 1         0.761   0.525   11    -6.900     1       0.0944        0.4400
# 2         0.612   0.807   10    -2.810     1       0.0336        0.0495
# 3         0.753   0.767    7    -3.773     1       0.0731        0.3090
# 4         0.841   0.479    0    -5.837     0       0.0376        0.2070
# 5         0.752   0.488    6    -7.050     1       0.0705        0.2970
# 6         0.381   0.594    3    -5.970     1       0.0486        0.3480
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000029    0.4150    0.441  153.960  audio_features
# 1          0.000007    0.0921    0.531   80.870  audio_features
# 2          0.017700    0.1010    0.398  124.053  audio_features
# 3          0.000000    0.2790    0.258  148.130  audio_features
# 4          0.000012    0.1220    0.454  112.968  audio_features
# ...
